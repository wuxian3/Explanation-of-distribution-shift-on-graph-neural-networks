# %% [markdown]
# # 基于Cora数据集的GCN节点分类

# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/FighterLYL/GraphNeuralNetwork/blob/master/chapter5/GCN_Cora.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
# </table>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#基于Cora数据集的GCN节点分类" data-toc-modified-id="基于Cora数据集的GCN节点分类-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>基于Cora数据集的GCN节点分类</a></span><ul class="toc-item"><li><span><a href="#SetUp" data-toc-modified-id="SetUp-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>SetUp</a></span></li><li><span><a href="#数据准备" data-toc-modified-id="数据准备-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>数据准备</a></span></li><li><span><a href="#图卷积层定义" data-toc-modified-id="图卷积层定义-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>图卷积层定义</a></span></li><li><span><a href="#模型定义" data-toc-modified-id="模型定义-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>模型定义</a></span></li><li><span><a href="#模型训练" data-toc-modified-id="模型训练-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>模型训练</a></span></li></ul></li></ul></div>

# %% [markdown]
# 在Colab中运行时可以通过`代码执行程序->更改运行时类型`选择使用`GPU`

# %% [markdown]
# ## SetUp

# %%
import itertools
import os, random
import os.path as osp
import pickle
import urllib
from collections import namedtuple
from scipy.sparse import coo_matrix
import numpy as np
import scipy.sparse as sp
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 数据准备

# %%
Data = namedtuple('Data', ['x', 'y', 'adjacency',
                           'train_mask', 'val_mask', 'test_mask'])


def tensor_from_numpy(x, device):
    return torch.from_numpy(x).to(device)


class CoraData(object):
    filenames = ["ind.cora.{}".format(name) for name in
                 ['x', 'tx', 'allx', 'y', 'ty', 'ally', 'graph', 'test.index']]

    def __init__(self, data_root="../data/cora", rebuild=False):
        """Cora数据，包括数据下载，处理，加载等功能
        当数据的缓存文件存在时，将使用缓存文件，否则将下载、进行处理，并缓存到磁盘

        处理之后的数据可以通过属性 .data 获得，它将返回一个数据对象，包括如下几部分：
            * x: 节点的特征，维度为 2708 * 1433，类型为 np.ndarray
            * y: 节点的标签，总共包括7个类别，类型为 np.ndarray
            * adjacency: 邻接矩阵，维度为 2708 * 2708，类型为 scipy.sparse.coo.coo_matrix
            * train_mask: 训练集掩码向量，维度为 2708，当节点属于训练集时，相应位置为True，否则False
            * val_mask: 验证集掩码向量，维度为 2708，当节点属于验证集时，相应位置为True，否则False
            * test_mask: 测试集掩码向量，维度为 2708，当节点属于测试集时，相应位置为True，否则False

        Args:
        -------
            data_root: string, optional
                存放数据的目录，原始数据路径: ../data/cora
                缓存数据路径: {data_root}/ch5_cached.pkl
            rebuild: boolean, optional
                是否需要重新构建数据集，当设为True时，如果存在缓存数据也会重建数据

        """
        current_path = os.getcwd()
        print(current_path)
        self.data_root = data_root
        save_file = osp.join(self.data_root, "ch5_cached.pkl")
        if osp.exists(save_file) and not rebuild:
            print("Using Cached file: {}".format(save_file))
            self._data = pickle.load(open(save_file, "rb"))
        else:
            self._data = self.process_data()
            with open(save_file, "wb") as f:
                pickle.dump(self.data, f)
            print("Cached file: {}".format(save_file))

    @property
    def data(self):
        """返回Data数据对象，包括x, y, adjacency, train_mask, val_mask, test_mask"""
        return self._data

    def process_data(self):
        """
        处理数据，得到节点特征和标签，邻接矩阵，训练集、验证集以及测试集
        引用自：https://github.com/rusty1s/pytorch_geometric
        """
        print("Process data ...")
        _, tx, allx, y, ty, ally, graph, test_index = [self.read_data(
            osp.join(self.data_root, name)) for name in self.filenames]
        train_index = np.arange(y.shape[0])
        val_index = np.arange(y.shape[0], y.shape[0] + 500)
        sorted_test_index = sorted(test_index)

        x = np.concatenate((allx, tx), axis=0)
        y = np.concatenate((ally, ty), axis=0).argmax(axis=1)

        x[test_index] = x[sorted_test_index]
        y[test_index] = y[sorted_test_index]
        num_nodes = x.shape[0]

        train_mask = np.zeros(num_nodes, dtype=np.bool)
        val_mask = np.zeros(num_nodes, dtype=np.bool)
        test_mask = np.zeros(num_nodes, dtype=np.bool)
        train_mask[train_index] = True
        val_mask[val_index] = True
        test_mask[test_index] = True
        adjacency = self.build_adjacency(graph)
        print("Node's feature shape: ", x.shape)
        print("Node's label shape: ", y.shape)
        print("Adjacency's shape: ", adjacency.shape)
        print("Number of training nodes: ", train_mask.sum())
        print("Number of validation nodes: ", val_mask.sum())
        print("Number of test nodes: ", test_mask.sum())

        return Data(x=x, y=y, adjacency=adjacency,
                    train_mask=train_mask, val_mask=val_mask, test_mask=test_mask)

    @staticmethod
    def build_adjacency(adj_dict):
        """根据邻接表创建邻接矩阵"""
        edge_index = []
        num_nodes = len(adj_dict)
        for src, dst in adj_dict.items():
            edge_index.extend([src, v] for v in dst)
            edge_index.extend([v, src] for v in dst)
        # 去除重复的边
        edge_index = list(k for k, _ in itertools.groupby(sorted(edge_index)))
        edge_index = np.asarray(edge_index)
        adjacency = sp.coo_matrix((np.ones(len(edge_index)),
                                   (edge_index[:, 0], edge_index[:, 1])),
                    shape=(num_nodes, num_nodes), dtype="float32")
        return adjacency

    @staticmethod
    def read_data(path):
        """使用不同的方式读取原始数据以进一步处理"""
        name = osp.basename(path)
        if name == "ind.cora.test.index":
            out = np.genfromtxt(path, dtype="int64")
            return out
        else:
            out = pickle.load(open(path, "rb"), encoding="latin1")
            out = out.toarray() if hasattr(out, "toarray") else out
            return out

    @staticmethod
    def normalization(adjacency):
        """计算 L=D^-0.5 * (A+I) * D^-0.5"""
        adjacency += sp.eye(adjacency.shape[0])    # 增加自连接
        degree = np.array(adjacency.sum(1))
        d_hat = sp.diags(np.power(degree, -0.5).flatten())
        return d_hat.dot(adjacency).dot(d_hat).tocoo()

# %% [markdown]
# ## 图卷积层定义

# %%
class GraphConvolution(nn.Module):
    def __init__(self, input_dim, output_dim, use_bias=True):
        """图卷积：L*X*\theta

        Args:
        ----------
            input_dim: int
                节点输入特征的维度
            output_dim: int
                输出特征维度
            use_bias : bool, optional
                是否使用偏置
        """
        super(GraphConvolution, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.use_bias = use_bias
        self.weight = nn.Parameter(torch.Tensor(input_dim, output_dim))
        if self.use_bias:
            self.bias = nn.Parameter(torch.Tensor(output_dim))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self):
        init.kaiming_uniform_(self.weight)
        if self.use_bias:
            init.zeros_(self.bias)

    def forward(self, adjacency, input_feature):
        """邻接矩阵是稀疏矩阵，因此在计算时使用稀疏矩阵乘法

        Args:
        -------
            adjacency: torch.sparse.FloatTensor
                邻接矩阵
            input_feature: torch.Tensor
                输入特征
        """
        support = torch.mm(input_feature, self.weight)
        output = torch.sparse.mm(adjacency, support)
        if self.use_bias:
            output += self.bias
        return output

    def __repr__(self):
        return self.__class__.__name__ + ' (' \
            + str(self.input_dim) + ' -> ' \
            + str(self.output_dim) + ')'

# %% [markdown]
# ## 模型定义
#
# 读者可以自己对GCN模型结构进行修改和实验

# %%
class GcnNet(nn.Module):
    """
    定义一个包含两层GraphConvolution的模型
    """
    def __init__(self, input_dim=1433):
        super(GcnNet, self).__init__()
        self.gcn1 = GraphConvolution(input_dim, 16)
        self.gcn2 = GraphConvolution(16, 7)

    def forward(self, adjacency, feature):
        h = F.relu(self.gcn1(adjacency, feature))
        logits = self.gcn2(adjacency, h)
        return logits

# %% [markdown]
# ## 模型训练

# %%
# 超参数定义
LEARNING_RATE = 0.1
WEIGHT_DACAY = 5e-4
EPOCHS = 200
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# 加载数据，并转换为torch.Tensor
dataset = CoraData().data
node_feature = dataset.x / dataset.x.sum(1, keepdims=True)  # 归一化数据，使得每一行和为1
tensor_x = tensor_from_numpy(node_feature, DEVICE)
tensor_y = tensor_from_numpy(dataset.y, DEVICE)
tensor_train_mask = tensor_from_numpy(dataset.train_mask, DEVICE)
tensor_val_mask = tensor_from_numpy(dataset.val_mask, DEVICE)
tensor_test_mask = tensor_from_numpy(dataset.test_mask, DEVICE)

# print(type(dataset.adjacency))
# print(dataset.adjacency)

normalize_adjacency = CoraData.normalization(dataset.adjacency)   # 规范化邻接矩阵

num_nodes, input_dim = node_feature.shape
indices = torch.from_numpy(np.asarray([normalize_adjacency.row, normalize_adjacency.col]).astype('int64')).long()
values = torch.from_numpy(normalize_adjacency.data.astype(np.float32))
tensor_adjacency = torch.sparse.FloatTensor(indices, values, (num_nodes, num_nodes)).to(DEVICE)

# print(tensor_adjacency)
# print(dataset.adjacency)
# Out:
# /content
# Using Cached file: ../data/cora/ch5_cached.pkl

# %%
# 模型定义：Model, Loss, Optimizer
model = GcnNet(input_dim).to(DEVICE)
criterion = nn.CrossEntropyLoss().to(DEVICE)
optimizer = optim.Adam(model.parameters(),
                       lr=LEARNING_RATE,
                       weight_decay=WEIGHT_DACAY)

# %%
# 训练主体函数
def train():
    loss_history = []
    val_acc_history = []
    model.train()
    train_y = tensor_y[tensor_train_mask]
    for epoch in range(EPOCHS):
        logits = model(tensor_adjacency, tensor_x)  # 前向传播
        train_mask_logits = logits[tensor_train_mask]   # 只选择训练节点进行监督
        loss = criterion(train_mask_logits, train_y)    # 计算损失值
        optimizer.zero_grad()
        loss.backward()     # 反向传播计算参数的梯度
        optimizer.step()    # 使用优化方法进行梯度更新
        train_acc, _, _ = test(tensor_train_mask)     # 计算当前模型训练集上的准确率
        val_acc, _, _ = test(tensor_val_mask)     # 计算当前模型在验证集上的准确率
        # 记录训练过程中损失值和准确率的变化，用于画图
        loss_history.append(loss.item())
        val_acc_history.append(val_acc.item())
        print("Epoch {:03d}: Loss {:.4f}, TrainAcc {:.4}, ValAcc {:.4f}".format(
            epoch, loss.item(), train_acc.item(), val_acc.item()))

    return loss_history, val_acc_history

# %%
# 测试函数
def test(mask):
    model.eval()
    with torch.no_grad():
        logits = model(tensor_adjacency, tensor_x)
        test_mask_logits = logits[mask]
        predict_y = test_mask_logits.max(1)[1]
        accuarcy = torch.eq(predict_y, tensor_y[mask]).float().mean()
    return accuarcy, test_mask_logits.cpu().numpy(), tensor_y[mask].cpu().numpy()

def get_y(tensor_adj=None):
  if tensor_adj is None:
    tensor_adj = tensor_adjacency
  model.eval()
  logits = model(tensor_adj, tensor_x)
  test_mask_logits = logits
  predict_y = test_mask_logits.max(1)[1]
  return predict_y
# print(get_y(tensor_test_mask))

# %%
def y_loss(y):
  cnt = 0
  ret_index = []
  ori_y = get_y()
  for i in range(y.shape[0]):
    if y[i] != ori_y[i]:
      cnt += 1
      ret_index.append("node {} from {} to {}".format(i, ori_y[i], y[i]))
  return cnt, ret_index

# %%
def plot_loss_with_acc(loss_history, val_acc_history):
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.plot(range(len(loss_history)), loss_history,
             c=np.array([255, 71, 90]) / 255.)
    plt.ylabel('Loss')

    ax2 = fig.add_subplot(111, sharex=ax1, frameon=False)
    ax2.plot(range(len(val_acc_history)), val_acc_history,
             c=np.array([79, 179, 255]) / 255.)
    ax2.yaxis.tick_right()
    ax2.yaxis.set_label_position("right")
    plt.ylabel('ValAcc')

    plt.xlabel('Epoch')
    plt.title('Training Loss & Validation Accuracy')
    plt.show()

# %%
loss, val_acc = train()
test_acc, test_logits, test_label = test(tensor_test_mask)
print("Test accuarcy: ", test_acc.item())
# Out:
# Epoch 000: Loss 1.9397, TrainAcc 0.2929, ValAcc 0.2320
# Epoch 001: Loss 1.8379, TrainAcc 0.5857, ValAcc 0.3460
# Epoch 002: Loss 1.7250, TrainAcc 0.8571, ValAcc 0.6400
# Epoch 003: Loss 1.5819, TrainAcc 0.8857, ValAcc 0.5740
# Epoch 004: Loss 1.4257, TrainAcc 0.9357, ValAcc 0.7360
# Epoch 005: Loss 1.2450, TrainAcc 0.9571, ValAcc 0.7640
# Epoch 006: Loss 1.0668, TrainAcc 0.9714, ValAcc 0.7380
# Epoch 007: Loss 0.8920, TrainAcc 0.9714, ValAcc 0.7340
# Epoch 008: Loss 0.7366, TrainAcc 0.9786, ValAcc 0.7780
# Epoch 009: Loss 0.6021, TrainAcc 0.9786, ValAcc 0.7960
# Epoch 010: Loss 0.4965, TrainAcc 0.9786, ValAcc 0.7960
# Epoch 011: Loss 0.4105, TrainAcc 0.9857, ValAcc 0.7700
# Epoch 012: Loss 0.3466, TrainAcc 0.9857, ValAcc 0.7780
# Epoch 013: Loss 0.2993, TrainAcc 0.9857, ValAcc 0.7980
# Epoch 014: Loss 0.2626, TrainAcc 0.9857, ValAcc 0.8000
# Epoch 015: Loss 0.2378, TrainAcc 0.9857, ValAcc 0.7860
# Epoch 016: Loss 0.2197, TrainAcc 1.0, ValAcc 0.7860
# Epoch 017: Loss 0.2078, TrainAcc 1.0, ValAcc 0.7860
# Epoch 018: Loss 0.2005, TrainAcc 1.0, ValAcc 0.7900
# Epoch 019: Loss 0.1966, TrainAcc 1.0, ValAcc 0.7860
# Epoch 020: Loss 0.1939, TrainAcc 1.0, ValAcc 0.7940
# Epoch 021: Loss 0.1936, TrainAcc 1.0, ValAcc 0.7940
# Epoch 022: Loss 0.1920, TrainAcc 1.0, ValAcc 0.7980
# Epoch 023: Loss 0.1906, TrainAcc 1.0, ValAcc 0.7900
# Epoch 024: Loss 0.1870, TrainAcc 1.0, ValAcc 0.7980
# Epoch 025: Loss 0.1826, TrainAcc 1.0, ValAcc 0.7940
# Epoch 026: Loss 0.1770, TrainAcc 1.0, ValAcc 0.7940
# Epoch 027: Loss 0.1705, TrainAcc 1.0, ValAcc 0.7860
# Epoch 028: Loss 0.1644, TrainAcc 1.0, ValAcc 0.7940
# Epoch 029: Loss 0.1578, TrainAcc 1.0, ValAcc 0.7940
# Epoch 030: Loss 0.1527, TrainAcc 1.0, ValAcc 0.7900
# Epoch 031: Loss 0.1474, TrainAcc 1.0, ValAcc 0.7880
# Epoch 032: Loss 0.1437, TrainAcc 1.0, ValAcc 0.7920
# Epoch 033: Loss 0.1404, TrainAcc 1.0, ValAcc 0.7940
# Epoch 034: Loss 0.1377, TrainAcc 1.0, ValAcc 0.7880
# Epoch 035: Loss 0.1357, TrainAcc 1.0, ValAcc 0.7940
# Epoch 036: Loss 0.1338, TrainAcc 1.0, ValAcc 0.7940
# Epoch 037: Loss 0.1321, TrainAcc 1.0, ValAcc 0.7940
# Epoch 038: Loss 0.1308, TrainAcc 1.0, ValAcc 0.7960
# Epoch 039: Loss 0.1291, TrainAcc 1.0, ValAcc 0.7880
# Epoch 040: Loss 0.1280, TrainAcc 1.0, ValAcc 0.7960
# Epoch 041: Loss 0.1276, TrainAcc 0.9929, ValAcc 0.7860
# Epoch 042: Loss 0.1302, TrainAcc 1.0, ValAcc 0.7900
# Epoch 043: Loss 0.1341, TrainAcc 0.9929, ValAcc 0.7740
# Epoch 044: Loss 0.1313, TrainAcc 1.0, ValAcc 0.7960
# Epoch 045: Loss 0.1178, TrainAcc 1.0, ValAcc 0.7940
# Epoch 046: Loss 0.1238, TrainAcc 1.0, ValAcc 0.7960
# Epoch 047: Loss 0.1197, TrainAcc 1.0, ValAcc 0.7900
# Epoch 048: Loss 0.1159, TrainAcc 1.0, ValAcc 0.7980
# Epoch 049: Loss 0.1196, TrainAcc 1.0, ValAcc 0.7920
# Epoch 050: Loss 0.1154, TrainAcc 1.0, ValAcc 0.7960
# Epoch 051: Loss 0.1185, TrainAcc 1.0, ValAcc 0.7960
# Epoch 052: Loss 0.1180, TrainAcc 1.0, ValAcc 0.8000
# Epoch 053: Loss 0.1174, TrainAcc 1.0, ValAcc 0.7880
# Epoch 054: Loss 0.1191, TrainAcc 1.0, ValAcc 0.7960
# Epoch 055: Loss 0.1167, TrainAcc 1.0, ValAcc 0.7920
# Epoch 056: Loss 0.1178, TrainAcc 1.0, ValAcc 0.8020
# Epoch 057: Loss 0.1167, TrainAcc 1.0, ValAcc 0.7900
# Epoch 058: Loss 0.1158, TrainAcc 1.0, ValAcc 0.7920
# Epoch 059: Loss 0.1157, TrainAcc 1.0, ValAcc 0.7940
# Epoch 060: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7960
# Epoch 061: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7940
# Epoch 062: Loss 0.1143, TrainAcc 1.0, ValAcc 0.7920
# Epoch 063: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7940
# Epoch 064: Loss 0.1143, TrainAcc 1.0, ValAcc 0.8040
# Epoch 065: Loss 0.1144, TrainAcc 1.0, ValAcc 0.7960
# Epoch 066: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7880
# Epoch 067: Loss 0.1140, TrainAcc 1.0, ValAcc 0.7980
# Epoch 068: Loss 0.1148, TrainAcc 1.0, ValAcc 0.8000
# Epoch 069: Loss 0.1145, TrainAcc 1.0, ValAcc 0.7860
# Epoch 070: Loss 0.1143, TrainAcc 1.0, ValAcc 0.7920
# Epoch 071: Loss 0.1146, TrainAcc 1.0, ValAcc 0.7960
# Epoch 072: Loss 0.1145, TrainAcc 1.0, ValAcc 0.7980
# Epoch 073: Loss 0.1143, TrainAcc 1.0, ValAcc 0.7940
# Epoch 074: Loss 0.1145, TrainAcc 1.0, ValAcc 0.7920
# Epoch 075: Loss 0.1142, TrainAcc 1.0, ValAcc 0.8000
# Epoch 076: Loss 0.1145, TrainAcc 1.0, ValAcc 0.7960
# Epoch 077: Loss 0.1142, TrainAcc 1.0, ValAcc 0.7920
# Epoch 078: Loss 0.1143, TrainAcc 1.0, ValAcc 0.7960
# Epoch 079: Loss 0.1144, TrainAcc 1.0, ValAcc 0.7980
# Epoch 080: Loss 0.1143, TrainAcc 1.0, ValAcc 0.7960
# Epoch 081: Loss 0.1145, TrainAcc 1.0, ValAcc 0.7940
# Epoch 082: Loss 0.1146, TrainAcc 1.0, ValAcc 0.7960
# Epoch 083: Loss 0.1146, TrainAcc 1.0, ValAcc 0.7960
# Epoch 084: Loss 0.1146, TrainAcc 1.0, ValAcc 0.7980
# Epoch 085: Loss 0.1147, TrainAcc 1.0, ValAcc 0.7920
# Epoch 086: Loss 0.1147, TrainAcc 1.0, ValAcc 0.7980
# Epoch 087: Loss 0.1147, TrainAcc 1.0, ValAcc 0.7940
# Epoch 088: Loss 0.1147, TrainAcc 1.0, ValAcc 0.7920
# Epoch 089: Loss 0.1147, TrainAcc 1.0, ValAcc 0.7980
# Epoch 090: Loss 0.1148, TrainAcc 1.0, ValAcc 0.7900
# Epoch 091: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7940
# Epoch 092: Loss 0.1148, TrainAcc 1.0, ValAcc 0.8000
# Epoch 093: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7900
# Epoch 094: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7960
# Epoch 095: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7980
# Epoch 096: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7960
# Epoch 097: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7940
# Epoch 098: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7960
# Epoch 099: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7980
# Epoch 100: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7960
# Epoch 101: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7960
# Epoch 102: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7960
# Epoch 103: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7960
# Epoch 104: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7960
# Epoch 105: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7940
# Epoch 106: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7980
# Epoch 107: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7940
# Epoch 108: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7980
# Epoch 109: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7960
# Epoch 110: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7960
# Epoch 111: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7960
# Epoch 112: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7980
# Epoch 113: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7940
# Epoch 114: Loss 0.1153, TrainAcc 1.0, ValAcc 0.8000
# Epoch 115: Loss 0.1153, TrainAcc 1.0, ValAcc 0.7920
# Epoch 116: Loss 0.1153, TrainAcc 1.0, ValAcc 0.8000
# Epoch 117: Loss 0.1153, TrainAcc 1.0, ValAcc 0.7920
# Epoch 118: Loss 0.1155, TrainAcc 1.0, ValAcc 0.8000
# Epoch 119: Loss 0.1155, TrainAcc 1.0, ValAcc 0.7900
# Epoch 120: Loss 0.1159, TrainAcc 1.0, ValAcc 0.8020
# Epoch 121: Loss 0.1164, TrainAcc 1.0, ValAcc 0.7920
# Epoch 122: Loss 0.1178, TrainAcc 1.0, ValAcc 0.8060
# Epoch 123: Loss 0.1191, TrainAcc 1.0, ValAcc 0.7900
# Epoch 124: Loss 0.1214, TrainAcc 1.0, ValAcc 0.8080
# Epoch 125: Loss 0.1202, TrainAcc 1.0, ValAcc 0.7960
# Epoch 126: Loss 0.1156, TrainAcc 1.0, ValAcc 0.7960
# Epoch 127: Loss 0.1111, TrainAcc 1.0, ValAcc 0.8040
# Epoch 128: Loss 0.1139, TrainAcc 1.0, ValAcc 0.7960
# Epoch 129: Loss 0.1174, TrainAcc 1.0, ValAcc 0.7940
# Epoch 130: Loss 0.1157, TrainAcc 1.0, ValAcc 0.7920
# Epoch 131: Loss 0.1146, TrainAcc 1.0, ValAcc 0.7920
# Epoch 132: Loss 0.1169, TrainAcc 1.0, ValAcc 0.8060
# Epoch 133: Loss 0.1187, TrainAcc 1.0, ValAcc 0.7940
# Epoch 134: Loss 0.1183, TrainAcc 1.0, ValAcc 0.7940
# Epoch 135: Loss 0.1155, TrainAcc 1.0, ValAcc 0.7920
# Epoch 136: Loss 0.1143, TrainAcc 1.0, ValAcc 0.7960
# Epoch 137: Loss 0.1155, TrainAcc 1.0, ValAcc 0.7980
# Epoch 138: Loss 0.1159, TrainAcc 1.0, ValAcc 0.7880
# Epoch 139: Loss 0.1153, TrainAcc 1.0, ValAcc 0.7900
# Epoch 140: Loss 0.1147, TrainAcc 1.0, ValAcc 0.8000
# Epoch 141: Loss 0.1155, TrainAcc 1.0, ValAcc 0.7860
# Epoch 142: Loss 0.1167, TrainAcc 1.0, ValAcc 0.7960
# Epoch 143: Loss 0.1162, TrainAcc 1.0, ValAcc 0.7980
# Epoch 144: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7940
# Epoch 145: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7960
# Epoch 146: Loss 0.1158, TrainAcc 1.0, ValAcc 0.7920
# Epoch 147: Loss 0.1160, TrainAcc 1.0, ValAcc 0.7960
# Epoch 148: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7940
# Epoch 149: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7960
# Epoch 150: Loss 0.1153, TrainAcc 1.0, ValAcc 0.7980
# Epoch 151: Loss 0.1157, TrainAcc 1.0, ValAcc 0.7940
# Epoch 152: Loss 0.1156, TrainAcc 1.0, ValAcc 0.8000
# Epoch 153: Loss 0.1153, TrainAcc 1.0, ValAcc 0.7920
# Epoch 154: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7960
# Epoch 155: Loss 0.1154, TrainAcc 1.0, ValAcc 0.7960
# Epoch 156: Loss 0.1155, TrainAcc 1.0, ValAcc 0.7940
# Epoch 157: Loss 0.1155, TrainAcc 1.0, ValAcc 0.8020
# Epoch 158: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7900
# Epoch 159: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7980
# Epoch 160: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7980
# Epoch 161: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7900
# Epoch 162: Loss 0.1153, TrainAcc 1.0, ValAcc 0.8020
# Epoch 163: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7920
# Epoch 164: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7980
# Epoch 165: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7960
# Epoch 166: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7920
# Epoch 167: Loss 0.1152, TrainAcc 1.0, ValAcc 0.8020
# Epoch 168: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7900
# Epoch 169: Loss 0.1153, TrainAcc 1.0, ValAcc 0.8000
# Epoch 170: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7940
# Epoch 171: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7920
# Epoch 172: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7980
# Epoch 173: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7920
# Epoch 174: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7980
# Epoch 175: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7940
# Epoch 176: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7980
# Epoch 177: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7960
# Epoch 178: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7980
# Epoch 179: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7940
# Epoch 180: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7960
# Epoch 181: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7940
# Epoch 182: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7960
# Epoch 183: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7920
# Epoch 184: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7960
# Epoch 185: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7920
# Epoch 186: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7960
# Epoch 187: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7960
# Epoch 188: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7960
# Epoch 189: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7960
# Epoch 190: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7920
# Epoch 191: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7960
# Epoch 192: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7920
# Epoch 193: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7960
# Epoch 194: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7920
# Epoch 195: Loss 0.1149, TrainAcc 1.0, ValAcc 0.8000
# Epoch 196: Loss 0.1149, TrainAcc 1.0, ValAcc 0.7940
# Epoch 197: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7980
# Epoch 198: Loss 0.1153, TrainAcc 1.0, ValAcc 0.7920
# Epoch 199: Loss 0.1159, TrainAcc 1.0, ValAcc 0.8000
# Test accuarcy:  0.8029999732971191

# %%
plot_loss_with_acc(loss, val_acc)

torch.save(model, 'gnn.pt')

# %%
# 绘制测试数据的TSNE降维图
from sklearn.manifold import TSNE
tsne = TSNE()
out = tsne.fit_transform(test_logits)
fig = plt.figure()
for i in range(7):
    indices = test_label == i
    x, y = out[indices].T
    plt.scatter(x, y, label=str(i))
plt.legend()

# %%
# 加载数据，并转换为torch.Tensor
dataset = CoraData().data
dim = dataset.x.shape
print(dim)

ori_y = get_y()
print(y_loss(ori_y))
# for i in range(ori_y.shape):
#   if

vals = []
indices = []

for val in tensor_adjacency._values():
  vals.append(val)


for s in tensor_adjacency._indices():
  indices.append(s)
  print(s)

print(len(indices))
print(len(vals))
# print(tensor_adjacency.shape)
# Out:
# /content
# Using Cached file: ../data/cora/ch5_cached.pkl
# (2708, 1433)
# (0, [])
# tensor([   0,    0,    0,  ..., 2707, 2707, 2707])
# tensor([   0,  633, 1862,  ..., 1473, 2706, 2707])
# 2
# 13264

# %%
def get_adj_tensor(tem_adj):
  normalize_adjacency = CoraData.normalization(tem_adj)   # 规范化邻接矩阵

  num_nodes, input_dim = node_feature.shape
  indices = torch.from_numpy(np.asarray([normalize_adjacency.row, normalize_adjacency.col]).astype('int64')).long()
  values = torch.from_numpy(normalize_adjacency.data.astype(np.float32))
  tensor_adjacency = torch.sparse.FloatTensor(indices, values, (num_nodes, num_nodes)).to(DEVICE)
  return tensor_adjacency

# %%
def explain(gap_num=20, test_num=100, save_file='explain.txt'):
  edge_num = len(indices[0])

  row = []
  col = []
  val = []

  ret_record = []

  for i in range(edge_num):
    x = int(indices[0][i])
    y = int(indices[1][i])
    if x == y:
      continue
    row.append(x)
    col.append(y)
    val.append(1.0)

  val_num = len(val)
  # print(val)

  ret_val = []
  fout = open(save_file, 'w')
  ret_rate = 0
  for _ in range(test_num):
    remove_edge = []
    for _ in range(gap_num):
      i = random.randint(0, len(row) - 1)
      pop_row = row.pop(i)
      pop_col = col.pop(i)
      pop_val = val.pop(i)
      remove_edge.append([pop_row, pop_col, pop_val])
    tem_row = np.array(row)
    tem_col = np.array(col)
    tem_val = np.array(val)
    tem_adj = coo_matrix((tem_val, (tem_row, tem_col)), shape=(num_nodes, num_nodes))

    tem_adj = get_adj_tensor(tem_adj)
    # print(tem_adj)
    tem_y = get_y(tem_adj)
    # print(tem_y)
    loss = y_loss(tem_y)
    # print(i, loss)
    write_str = "remove edge:{}: \nLoss {}\n".format(
              remove_edge, loss[0]) + str(loss[1]) + '\n\n'
    if loss[0] > 0:
      ret_record.append(write_str)
    fout.write(write_str)
    # print(write_str)
    for r, c, v in remove_edge:
      row.append(r)
      col.append(c)
      val.append(v)
    ret_rate += loss[0]
  fout.close()
  return ret_record, ret_rate / (test_num * gap_num)

record, rate = explain(100, 100, 'explain_1.txt')
for r in record:
  print(r)
print('change rate:', rate)
# Out:
# remove edge:[[1800, 852, 1.0], [2220, 2221, 1.0], [887, 1623, 1.0], [1358, 1722, 1.0], [1358, 357, 1.0], [1480, 1103, 1.0], [1663, 2577, 1.0], [2204, 2521, 1.0], [1126, 1823, 1.0], [711, 2111, 1.0], [36, 1640, 1.0], [2706, 2707, 1.0], [1174, 815, 1.0], [2370, 2368, 1.0], [1618, 1789, 1.0], [2592, 793, 1.0], [55, 323, 1.0], [6, 1602, 1.0], [2071, 2015, 1.0], [733, 218, 1.0], [1198, 1042, 1.0], [1695, 2133, 1.0], [152, 884, 1.0], [1796, 1794, 1.0], [1094, 89, 1.0], [1737, 2616, 1.0], [226, 1701, 1.0], [1997, 1986, 1.0], [2528, 826, 1.0], [1416, 74, 1.0], [743, 1986, 1.0], [39, 22, 1.0], [277, 1869, 1.0], [492, 2673, 1.0], [1019, 1457, 1.0], [77, 659, 1.0], [270, 2280, 1.0], [2442, 2530, 1.0], [1013, 1583, 1.0], [487, 2080, 1.0], [1695, 276, 1.0], [2290, 2464, 1.0], [1623, 608, 1.0], [1683, 2132, 1.0], [1358, 876, 1.0], [1555, 1470, 1.0], [1051, 2383, 1.0], [1667, 651, 1.0], [507, 251, 1.0], [1175, 2359, 1.0], [231, 179, 1.0], [30, 697, 1.0], [258, 963, 1.0], [542, 1245, 1.0], [1967, 275, 1.0], [812, 1542, 1.0], [745, 743, 1.0], [1535, 1916, 1.0], [1358, 613, 1.0], [1911, 1296, 1.0], [586, 1224, 1.0], [1219, 994, 1.0], [2218, 1459, 1.0], [1912, 1338, 1.0], [613, 341, 1.0], [2162, 1080, 1.0], [1395, 2189, 1.0], [1912, 1609, 1.0], [869, 232, 1.0], [1273, 2034, 1.0], [1358, 53, 1.0], [1662, 48, 1.0], [56, 1616, 1.0], [1368, 1911, 1.0], [306, 1787, 1.0], [1272, 1945, 1.0], [1230, 1050, 1.0], [506, 1352, 1.0], [2008, 1986, 1.0], [1592, 2485, 1.0], [2340, 2339, 1.0], [1274, 239, 1.0], [405, 1275, 1.0], [429, 1807, 1.0], [409, 1681, 1.0], [1013, 471, 1.0], [2103, 1912, 1.0], [1267, 645, 1.0], [434, 1693, 1.0], [1191, 1558, 1.0], [11, 1655, 1.0], [1723, 1724, 1.0], [1314, 514, 1.0], [1507, 2436, 1.0], [1118, 1042, 1.0], [997, 1837, 1.0], [629, 534, 1.0], [1659, 5, 1.0], [1215, 1894, 1.0], [403, 2503, 1.0]]:
# Loss 16
# ['node 252 from 5 to 6', 'node 382 from 4 to 3', 'node 506 from 0 to 6', 'node 571 from 3 to 5', 'node 679 from 3 to 0', 'node 733 from 3 to 4', 'node 743 from 3 to 0', 'node 755 from 5 to 6', 'node 1111 from 4 to 3', 'node 1131 from 5 to 0', 'node 1198 from 0 to 3', 'node 1230 from 4 to 3', 'node 1695 from 0 to 5', 'node 2103 from 0 to 3', 'node 2262 from 4 to 3', 'node 2496 from 5 to 4']
#
#
# Loss 11
# ['node 252 from 5 to 6', 'node 267 from 0 to 4', 'node 351 from 3 to 0', 'node 382 from 4 to 3', 'node 516 from 0 to 5', 'node 1523 from 0 to 5', 'node 1869 from 3 to 4', 'node 2104 from 3 to 5', 'node 2553 from 0 to 5', 'node 2562 from 0 to 3', 'node 2594 from 4 to 3']
#
#
# remove edge:[[1306, 364, 1.0], [1979, 2405, 1.0], [152, 43, 1.0], [316, 2004, 1.0], [1330, 2068, 1.0], [1475, 1017, 1.0], [1810, 351, 1.0], [328, 290, 1.0], [2372, 687, 1.0], [740, 1002, 1.0], [109, 2094, 1.0], [577, 394, 1.0], [64, 2616, 1.0], [1257, 2671, 1.0], [840, 1903, 1.0], [136, 831, 1.0], [80, 2049, 1.0], [2695, 2694, 1.0], [1824, 1825, 1.0], [2247, 2543, 1.0], [1708, 467, 1.0], [2074, 2181, 1.0], [1903, 1902, 1.0], [2394, 1399, 1.0], [2330, 2203, 1.0], [1472, 2187, 1.0], [33, 286, 1.0], [2438, 2437, 1.0], [2645, 29, 1.0], [581, 1623, 1.0], [2166, 118, 1.0], [1278, 2305, 1.0], [803, 2100, 1.0], [910, 139, 1.0], [1068, 810, 1.0], [1583, 973, 1.0], [2305, 2306, 1.0], [1267, 1824, 1.0], [1138, 2250, 1.0], [514, 478, 1.0], [981, 1221, 1.0], [1701, 1872, 1.0], [2314, 1708, 1.0], [1825, 1183, 1.0], [326, 154, 1.0], [2001, 2335, 1.0], [2546, 628, 1.0], [463, 1966, 1.0], [1864, 869, 1.0], [1542, 1176, 1.0], [1889, 429, 1.0], [934, 94, 1.0], [623, 2464, 1.0], [1276, 458, 1.0], [1681, 407, 1.0], [588, 33, 1.0], [796, 1103, 1.0], [2002, 1986, 1.0], [1724, 2216, 1.0], [2227, 266, 1.0], [2027, 2360, 1.0], [2196, 2181, 1.0], [581, 306, 1.0], [240, 172, 1.0], [965, 2197, 1.0], [95, 861, 1.0], [1993, 1986, 1.0], [145, 537, 1.0], [870, 1119, 1.0], [2457, 2458, 1.0], [1026, 2034, 1.0], [2227, 634, 1.0], [2349, 1469, 1.0], [2135, 2282, 1.0], [1772, 109, 1.0], [1358, 1599, 1.0], [1952, 1002, 1.0], [640, 894, 1.0], [320, 1597, 1.0], [2203, 731, 1.0], [211, 356, 1.0], [507, 1211, 1.0], [160, 2009, 1.0], [1095, 1325, 1.0], [818, 415, 1.0], [281, 1382, 1.0], [2418, 2021, 1.0], [1702, 1240, 1.0], [1908, 1677, 1.0], [2707, 598, 1.0], [688, 492, 1.0], [1599, 1199, 1.0], [567, 631, 1.0], [661, 1884, 1.0], [1265, 2291, 1.0], [2045, 699, 1.0], [2651, 59, 1.0], [56, 1616, 1.0], [302, 719, 1.0], [2555, 961, 1.0]]:
# Loss 11
# ['node 309 from 4 to 3', 'node 504 from 6 to 0', 'node 600 from 4 to 0', 'node 803 from 6 to 5', 'node 830 from 6 to 5', 'node 934 from 0 to 4', 'node 1399 from 6 to 5', 'node 2027 from 3 to 0', 'node 2330 from 0 to 1', 'node 2347 from 0 to 4', 'node 2460 from 3 to 2']
#
#
# remove edge:[[2488, 85, 1.0], [2045, 308, 1.0], [997, 1837, 1.0], [1692, 756, 1.0], [1681, 1012, 1.0], [429, 2041, 1.0], [1742, 1427, 1.0], [2466, 533, 1.0], [2134, 1351, 1.0], [2336, 2335, 1.0], [507, 1176, 1.0], [1309, 2103, 1.0], [316, 1297, 1.0], [1358, 876, 1.0], [1797, 1072, 1.0], [1158, 2252, 1.0], [63, 1322, 1.0], [2327, 1778, 1.0], [1463, 2133, 1.0], [1388, 734, 1.0], [1051, 911, 1.0], [2337, 2259, 1.0], [1911, 2553, 1.0], [1217, 230, 1.0], [1579, 1183, 1.0], [381, 148, 1.0], [844, 472, 1.0], [1152, 2155, 1.0], [2, 1986, 1.0], [1527, 860, 1.0], [405, 1275, 1.0], [489, 2391, 1.0], [1191, 2339, 1.0], [1863, 1701, 1.0], [2162, 30, 1.0], [1629, 1711, 1.0], [1870, 1986, 1.0], [95, 2074, 1.0], [439, 1169, 1.0], [434, 2133, 1.0], [2103, 1309, 1.0], [306, 1770, 1.0], [1475, 2470, 1.0], [851, 1309, 1.0], [230, 549, 1.0], [48, 598, 1.0], [264, 1826, 1.0], [2306, 453, 1.0], [2394, 724, 1.0], [850, 2278, 1.0], [1542, 1931, 1.0], [839, 485, 1.0], [1042, 74, 1.0], [901, 1042, 1.0], [1763, 1736, 1.0], [556, 1623, 1.0], [2540, 2539, 1.0], [582, 2549, 1.0], [2226, 84, 1.0], [661, 1879, 1.0], [279, 242, 1.0], [1839, 2453, 1.0], [1894, 2034, 1.0], [1623, 660, 1.0], [2045, 1856, 1.0], [797, 1358, 1.0], [1358, 1721, 1.0], [1588, 1047, 1.0], [1593, 145, 1.0], [2423, 279, 1.0], [329, 1798, 1.0], [1451, 2564, 1.0], [1896, 793, 1.0], [2394, 471, 1.0], [1243, 1041, 1.0], [2405, 1980, 1.0], [1778, 1624, 1.0], [1899, 388, 1.0], [912, 2130, 1.0], [934, 94, 1.0], [973, 2153, 1.0], [1725, 1734, 1.0], [2016, 842, 1.0], [2068, 861, 1.0], [1411, 2218, 1.0], [146, 1927, 1.0], [180, 791, 1.0], [777, 702, 1.0], [510, 1131, 1.0], [94, 2355, 1.0], [827, 1039, 1.0], [2093, 109, 1.0], [1654, 1952, 1.0], [470, 1115, 1.0], [1111, 1273, 1.0], [1190, 1387, 1.0], [441, 2184, 1.0], [24, 598, 1.0], [998, 1431, 1.0], [2143, 1787, 1.0]]:
# Loss 13
# ['node 600 from 4 to 0', 'node 777 from 0 to 6', 'node 830 from 6 to 5', 'node 888 from 2 to 0', 'node 934 from 0 to 4', 'node 1119 from 3 to 4', 'node 1131 from 5 to 0', 'node 2016 from 6 to 5', 'node 2103 from 0 to 3', 'node 2129 from 3 to 4', 'node 2259 from 3 to 4', 'node 2263 from 0 to 4', 'node 2337 from 3 to 4']
#
#
# remove edge:[[1765, 2492, 1.0], [2276, 1844, 1.0], [2386, 299, 1.0], [1956, 807, 1.0], [1106, 1092, 1.0], [388, 1899, 1.0], [552, 2201, 1.0], [2335, 2259, 1.0], [1927, 405, 1.0], [1693, 1391, 1.0], [1358, 645, 1.0], [735, 2061, 1.0], [1924, 1927, 1.0], [995, 1912, 1.0], [1699, 1065, 1.0], [2069, 702, 1.0], [310, 1815, 1.0], [2112, 711, 1.0], [31, 1594, 1.0], [598, 1003, 1.0], [583, 2224, 1.0], [893, 911, 1.0], [1701, 1871, 1.0], [266, 2229, 1.0], [1815, 310, 1.0], [979, 1957, 1.0], [2333, 1042, 1.0], [1750, 1765, 1.0], [733, 1294, 1.0], [2706, 1473, 1.0], [431, 2694, 1.0], [898, 1835, 1.0], [1103, 796, 1.0], [2359, 1834, 1.0], [1914, 1676, 1.0], [579, 1134, 1.0], [2399, 43, 1.0], [2144, 135, 1.0], [704, 2113, 1.0], [359, 1483, 1.0], [1973, 504, 1.0], [1810, 835, 1.0], [312, 1740, 1.0], [826, 610, 1.0], [809, 548, 1.0], [515, 2465, 1.0], [2249, 2518, 1.0], [1623, 1775, 1.0], [523, 2406, 1.0], [1358, 626, 1.0], [190, 491, 1.0], [1216, 2446, 1.0], [110, 1262, 1.0], [59, 580, 1.0], [465, 1869, 1.0], [1301, 25, 1.0], [822, 1973, 1.0], [2228, 1396, 1.0], [1986, 1997, 1.0], [623, 444, 1.0], [306, 236, 1.0], [1035, 1740, 1.0], [1908, 1178, 1.0], [394, 577, 1.0], [2485, 1370, 1.0], [454, 2188, 1.0], [2203, 731, 1.0], [2457, 499, 1.0], [1857, 1708, 1.0], [93, 550, 1.0], [481, 2291, 1.0], [299, 2383, 1.0], [28, 1687, 1.0], [93, 1495, 1.0], [55, 323, 1.0], [1810, 1817, 1.0], [1558, 2339, 1.0], [903, 2031, 1.0], [1914, 41, 1.0], [244, 565, 1.0], [1900, 2608, 1.0], [219, 1542, 1.0], [2502, 858, 1.0], [1919, 1402, 1.0], [350, 1778, 1.0], [1121, 1810, 1.0], [1623, 1773, 1.0], [1565, 1358, 1.0], [2269, 1619, 1.0], [2024, 651, 1.0], [88, 1174, 1.0], [90, 156, 1.0], [606, 531, 1.0], [1257, 1206, 1.0], [429, 2041, 1.0], [1178, 2350, 1.0], [1131, 2283, 1.0], [505, 1560, 1.0], [1133, 2185, 1.0], [1150, 1243, 1.0]]:
# Loss 11
# ['node 252 from 5 to 6', 'node 388 from 5 to 6', 'node 577 from 3 to 4', 'node 733 from 3 to 4', 'node 885 from 5 to 4', 'node 995 from 0 to 3', 'node 1377 from 0 to 6', 'node 2024 from 0 to 5', 'node 2228 from 6 to 5', 'node 2498 from 4 to 5', 'node 2502 from 0 to 1']
#
#
# remove edge:[[387, 519, 1.0], [2025, 1357, 1.0], [1131, 2155, 1.0], [439, 1169, 1.0], [1911, 2553, 1.0], [2297, 1796, 1.0], [2649, 2457, 1.0], [1753, 1358, 1.0], [501, 1358, 1.0], [1490, 306, 1.0], [1684, 2513, 1.0], [1803, 77, 1.0], [30, 2162, 1.0], [1119, 1235, 1.0], [735, 739, 1.0], [1954, 1956, 1.0], [1781, 2107, 1.0], [798, 1795, 1.0], [924, 638, 1.0], [609, 1041, 1.0], [2416, 1152, 1.0], [819, 364, 1.0], [1862, 0, 1.0], [665, 332, 1.0], [961, 1728, 1.0], [2130, 1889, 1.0], [411, 2609, 1.0], [456, 544, 1.0], [849, 394, 1.0], [337, 1214, 1.0], [1405, 1053, 1.0], [2371, 2367, 1.0], [823, 1765, 1.0], [391, 493, 1.0], [1358, 1723, 1.0], [1647, 1504, 1.0], [2274, 1527, 1.0], [263, 1103, 1.0], [820, 889, 1.0], [776, 402, 1.0], [1870, 1986, 1.0], [1841, 2056, 1.0], [840, 1903, 1.0], [875, 1950, 1.0], [243, 2474, 1.0], [1880, 479, 1.0], [2349, 1185, 1.0], [2045, 215, 1.0], [1914, 1359, 1.0], [1901, 1954, 1.0], [2182, 2180, 1.0], [1987, 1986, 1.0], [2160, 1698, 1.0], [24, 17, 1.0], [1203, 461, 1.0], [2595, 833, 1.0], [584, 623, 1.0], [505, 1258, 1.0], [2127, 546, 1.0], [1941, 507, 1.0], [608, 306, 1.0], [1950, 892, 1.0], [853, 1169, 1.0], [965, 839, 1.0], [2420, 640, 1.0], [1358, 1550, 1.0], [1108, 390, 1.0], [95, 456, 1.0], [2137, 1394, 1.0], [151, 1986, 1.0], [748, 1358, 1.0], [2359, 1171, 1.0], [720, 1441, 1.0], [157, 1870, 1.0], [1781, 1998, 1.0], [911, 1534, 1.0], [1358, 831, 1.0], [1975, 1421, 1.0], [356, 498, 1.0], [2411, 2410, 1.0], [1743, 2450, 1.0], [306, 124, 1.0], [1199, 1599, 1.0], [255, 2112, 1.0], [1947, 310, 1.0], [1699, 1065, 1.0], [1209, 64, 1.0], [458, 1122, 1.0], [1072, 1803, 1.0], [1536, 1228, 1.0], [59, 1725, 1.0], [1952, 2206, 1.0], [1978, 621, 1.0], [702, 993, 1.0], [707, 763, 1.0], [2015, 88, 1.0], [1165, 537, 1.0], [1623, 1776, 1.0], [2058, 2150, 1.0], [183, 997, 1.0]]:
# Loss 14
# ['node 255 from 6 to 4', 'node 382 from 4 to 3', 'node 748 from 2 to 0', 'node 798 from 4 to 5', 'node 830 from 6 to 5', 'node 1110 from 5 to 6', 'node 1119 from 3 to 4', 'node 2137 from 0 to 6', 'node 2274 from 0 to 5', 'node 2371 from 3 to 6', 'node 2420 from 3 to 0', 'node 2595 from 3 to 1', 'node 2637 from 1 to 4', 'node 2649 from 6 to 5']
#
#
# remove edge:[[1701, 1479, 1.0], [1782, 1798, 1.0], [1042, 1025, 1.0], [2124, 2127, 1.0], [1090, 1271, 1.0], [1724, 1723, 1.0], [1229, 1627, 1.0], [2670, 2679, 1.0], [306, 329, 1.0], [2367, 2177, 1.0], [2449, 1523, 1.0], [896, 465, 1.0], [2075, 775, 1.0], [963, 203, 1.0], [109, 318, 1.0], [845, 598, 1.0], [1920, 69, 1.0], [1203, 1842, 1.0], [1978, 478, 1.0], [1125, 2332, 1.0], [2695, 2694, 1.0], [154, 2525, 1.0], [1464, 1013, 1.0], [1984, 651, 1.0], [2577, 1663, 1.0], [580, 2444, 1.0], [1208, 187, 1.0], [90, 156, 1.0], [1529, 1417, 1.0], [1482, 1402, 1.0], [1131, 2185, 1.0], [915, 2415, 1.0], [88, 1908, 1.0], [894, 640, 1.0], [1472, 512, 1.0], [498, 356, 1.0], [596, 644, 1.0], [1744, 1358, 1.0], [1506, 1146, 1.0], [1555, 2363, 1.0], [369, 385, 1.0], [2286, 1901, 1.0], [2420, 640, 1.0], [853, 1358, 1.0], [2080, 1459, 1.0], [792, 2555, 1.0], [348, 2248, 1.0], [767, 2314, 1.0], [1951, 1952, 1.0], [1726, 1483, 1.0], [1741, 1309, 1.0], [15, 1093, 1.0], [2648, 2473, 1.0], [540, 113, 1.0], [1409, 1553, 1.0], [2346, 1692, 1.0], [118, 1029, 1.0], [277, 973, 1.0], [1977, 1526, 1.0], [1292, 689, 1.0], [2485, 1851, 1.0], [1483, 1358, 1.0], [67, 2628, 1.0], [448, 1826, 1.0], [869, 1701, 1.0], [771, 1156, 1.0], [1239, 743, 1.0], [1224, 2151, 1.0], [767, 873, 1.0], [2077, 1020, 1.0], [2471, 2493, 1.0], [1701, 1846, 1.0], [99, 26, 1.0], [1358, 689, 1.0], [1079, 1914, 1.0], [2415, 2597, 1.0], [2236, 151, 1.0], [1576, 1331, 1.0], [1961, 1022, 1.0], [1933, 507, 1.0], [2383, 299, 1.0], [1717, 2560, 1.0], [981, 1159, 1.0], [1309, 2015, 1.0], [408, 734, 1.0], [758, 111, 1.0], [900, 639, 1.0], [2017, 130, 1.0], [615, 59, 1.0], [1899, 388, 1.0], [1746, 1358, 1.0], [2679, 2682, 1.0], [1245, 306, 1.0], [598, 1473, 1.0], [1505, 1699, 1.0], [2272, 1441, 1.0], [2003, 185, 1.0], [341, 2045, 1.0], [1358, 1748, 1.0], [841, 2034, 1.0]]:
# Loss 16
# ['node 498 from 0 to 5', 'node 571 from 3 to 5', 'node 1079 from 0 to 4', 'node 1119 from 3 to 4', 'node 1131 from 5 to 0', 'node 1288 from 5 to 0', 'node 1291 from 5 to 6', 'node 1506 from 1 to 2', 'node 1660 from 5 to 6', 'node 1678 from 3 to 2', 'node 1981 from 5 to 0', 'node 2208 from 5 to 1', 'node 2272 from 5 to 6', 'node 2347 from 0 to 4', 'node 2420 from 3 to 0', 'node 2449 from 0 to 6']
#
#
, 1.0], [306, 1798, 1.0], [1520, 1750, 1.0], [904, 132, 1.0], [1059, 1600, 1.0], [2140, 927, 1.0], [1195, 270, 1.0], [2054, 1042, 1.0], [1637, 1973, 1.0], [2537, 259, 1.0], [1623, 1768, 1.0], [1401, 258, 1.0], [1340, 1943, 1.0], [1413, 872, 1.0], [1051, 2383, 1.0], [343, 1701, 1.0], [1526, 2425, 1.0], [2127, 1119, 1.0], [131, 834, 1.0], [1070, 728, 1.0], [2242, 2241, 1.0], [1441, 1619, 1.0], [2108, 693, 1.0], [2443, 1742, 1.0], [1986, 1023, 1.0], [342, 1512, 1.0], [326, 154, 1.0], [2269, 392, 1.0], [1721, 1358, 1.0], [1407, 1263, 1.0], [1701, 416, 1.0], [1275, 1468, 1.0], [2652, 357, 1.0], [1953, 1555, 1.0], [1457, 1019, 1.0], [67, 2628, 1.0], [2003, 2001, 1.0], [1417, 1452, 1.0], [1464, 850, 1.0], [244, 1072, 1.0], [140, 623, 1.0], [1620, 359, 1.0], [1334, 1542, 1.0], [1557, 650, 1.0], [1300, 877, 1.0], [224, 2034, 1.0], [1381, 1794, 1.0], [2611, 1239, 1.0], [2224, 2225, 1.0], [2031, 903, 1.0], [1499, 1358, 1.0], [908, 1013, 1.0], [2024, 478, 1.0], [2365, 970, 1.0], [2035, 1324, 1.0], [838, 868, 1.0], [1284, 1358, 1.0], [1380, 1379, 1.0], [2634, 2635, 1.0], [2402, 2403, 1.0], [2363, 1555, 1.0]]:
# Loss 16
# ['node 376 from 6 to 5', 'node 733 from 3 to 4', 'node 943 from 1 to 4', 'node 1131 from 5 to 0', 'node 1239 from 4 to 0', 'node 1263 from 2 to 6', 'node 1268 from 4 to 0', 'node 1407 from 2 to 6', 'node 1981 from 5 to 0', 'node 2003 from 4 to 3', 'node 2024 from 0 to 5', 'node 2035 from 3 to 4', 'node 2108 from 0 to 5', 'node 2262 from 4 to 3', 'node 2300 from 1 to 4', 'node 2611 from 4 to 0']
#
#
# remove edge:[[1131, 2280, 1.0], [155, 1689, 1.0], [1070, 1725, 1.0], [428, 2671, 1.0], [1176, 295, 1.0], [522, 2097, 1.0], [2516, 2517, 1.0], [1229, 1254, 1.0], [1025, 373, 1.0], [351, 1810, 1.0], [1961, 703, 1.0], [2496, 2290, 1.0], [194, 2646, 1.0], [1251, 1448, 1.0], [1367, 1656, 1.0], [2453, 1839, 1.0], [2026, 2096, 1.0], [687, 1171, 1.0], [36, 1146, 1.0], [1403, 465, 1.0], [2265, 1324, 1.0], [1984, 651, 1.0], [2358, 1460, 1.0], [2009, 745, 1.0], [2147, 374, 1.0], [2286, 2285, 1.0], [1020, 2077, 1.0], [2674, 2671, 1.0], [1358, 1072, 1.0], [1912, 2404, 1.0], [2359, 1136, 1.0], [1409, 1826, 1.0], [426, 1782, 1.0], [43, 963, 1.0], [485, 62, 1.0], [2685, 732, 1.0], [2597, 1725, 1.0], [1090, 2367, 1.0], [1219, 78, 1.0], [2456, 672, 1.0], [1443, 761, 1.0], [1663, 2577, 1.0], [1749, 1358, 1.0], [1231, 653, 1.0], [160, 553, 1.0], [1051, 2383, 1.0], [1610, 2556, 1.0], [2329, 137, 1.0], [240, 756, 1.0], [938, 2027, 1.0], [868, 988, 1.0], [444, 488, 1.0], [1047, 2333, 1.0], [544, 2199, 1.0], [743, 88, 1.0], [735, 1881, 1.0], [598, 157, 1.0], [1397, 861, 1.0], [336, 1944, 1.0], [2240, 2238, 1.0], [2096, 1856, 1.0], [1681, 695, 1.0], [2383, 1051, 1.0], [1645, 1343, 1.0], [628, 1169, 1.0], [996, 428, 1.0], [1235, 2126, 1.0], [1908, 211, 1.0], [836, 1343, 1.0], [1367, 124, 1.0], [258, 1240, 1.0], [1101, 509, 1.0], [699, 2327, 1.0], [2519, 2115, 1.0], [1358, 154, 1.0], [52, 1467, 1.0], [935, 661, 1.0], [2451, 2390, 1.0], [2045, 341, 1.0], [412, 1849, 1.0], [779, 1919, 1.0], [570, 2430, 1.0], [2645, 1443, 1.0], [1038, 565, 1.0], [2240, 1530, 1.0], [1358, 1480, 1.0], [1856, 1701, 1.0], [1571, 1045, 1.0], [2058, 1378, 1.0], [1448, 2034, 1.0], [2281, 2405, 1.0], [1481, 2335, 1.0], [935, 1873, 1.0], [308, 306, 1.0], [380, 2569, 1.0], [1553, 371, 1.0], [1476, 1170, 1.0], [2686, 1554, 1.0], [2688, 2687, 1.0], [1067, 2448, 1.0]]:
# Loss 15
# ['node 336 from 3 to 0', 'node 351 from 3 to 0', 'node 376 from 6 to 5', 'node 699 from 1 to 3', 'node 830 from 6 to 5', 'node 988 from 3 to 4', 'node 995 from 0 to 3', 'node 1219 from 4 to 3', 'node 1338 from 0 to 3', 'node 1912 from 0 to 3', 'node 2102 from 0 to 3', 'node 2103 from 0 to 3', 'node 2347 from 0 to 4', 'node 2358 from 3 to 2', 'node 2453 from 0 to 6']
#
#
# remove edge:[[1748, 1103, 1.0], [2680, 2594, 1.0], [226, 1701, 1.0], [1552, 36, 1.0], [505, 1251, 1.0], [2158, 2157, 1.0], [2051, 1042, 1.0], [776, 1542, 1.0], [1792, 581, 1.0], [593, 1474, 1.0], [2517, 2516, 1.0], [2216, 421, 1.0], [343, 311, 1.0], [304, 2423, 1.0], [1039, 436, 1.0], [1225, 1450, 1.0], [492, 2678, 1.0], [1282, 684, 1.0], [1698, 2160, 1.0], [954, 677, 1.0], [2163, 1348, 1.0], [177, 2682, 1.0], [231, 1701, 1.0], [1876, 1986, 1.0], [1964, 1965, 1.0], [341, 1389, 1.0], [239, 910, 1.0], [1245, 1144, 1.0], [230, 1095, 1.0], [1358, 919, 1.0], [1372, 42, 1.0], [300, 88, 1.0], [1473, 2706, 1.0], [1995, 1583, 1.0], [2165, 118, 1.0], [1832, 889, 1.0], [962, 1810, 1.0], [1520, 1765, 1.0], [1070, 1072, 1.0], [374, 846, 1.0], [2703, 1298, 1.0], [1948, 310, 1.0], [2246, 2245, 1.0], [2126, 2125, 1.0], [2038, 293, 1.0], [375, 2435, 1.0], [1906, 210, 1.0], [2238, 22, 1.0], [1559, 1260, 1.0], [456, 2472, 1.0], [1256, 1016, 1.0], [2187, 1692, 1.0], [241, 1441, 1.0], [154, 364, 1.0], [2181, 2074, 1.0], [2233, 2182, 1.0], [1311, 468, 1.0], [2295, 897, 1.0], [762, 859, 1.0], [820, 800, 1.0], [2464, 2289, 1.0], [1184, 1190, 1.0], [594, 663, 1.0], [2301, 733, 1.0], [2016, 2010, 1.0], [1441, 2271, 1.0], [2045, 215, 1.0], [1953, 1555, 1.0], [2415, 915, 1.0], [1584, 1367, 1.0], [737, 1630, 1.0], [485, 2219, 1.0], [519, 1346, 1.0], [1072, 20, 1.0], [1184, 2100, 1.0], [2412, 469, 1.0], [1281, 1748, 1.0], [48, 2206, 1.0], [1804, 1740, 1.0], [92, 1836, 1.0], [392, 720, 1.0], [1911, 2553, 1.0], [1388, 964, 1.0], [935, 854, 1.0], [1919, 1914, 1.0], [53, 1103, 1.0], [55, 2021, 1.0], [160, 743, 1.0], [1583, 366, 1.0], [735, 701, 1.0], [574, 2001, 1.0], [1810, 1809, 1.0], [702, 1637, 1.0], [568, 1116, 1.0], [2004, 316, 1.0], [903, 2031, 1.0], [802, 121, 1.0], [482, 2307, 1.0], [1307, 922, 1.0], [306, 1251, 1.0]]:
# Loss 10
# ['node 577 from 3 to 4', 'node 593 from 4 to 0', 'node 830 from 6 to 5', 'node 941 from 6 to 5', 'node 1110 from 5 to 6', 'node 1832 from 2 to 0', 'node 2016 from 6 to 5', 'node 2101 from 6 to 0', 'node 2126 from 4 to 3', 'node 2149 from 3 to 4']
#
#
# remove edge:[[2285, 2286, 1.0], [2261, 718, 1.0], [1028, 661, 1.0], [223, 1154, 1.0], [316, 845, 1.0], [549, 230, 1.0], [27, 2360, 1.0], [1131, 490, 1.0], [732, 296, 1.0], [2491, 1360, 1.0], [1505, 1072, 1.0], [2451, 752, 1.0], [1701, 767, 1.0], [1358, 1738, 1.0], [153, 236, 1.0], [27, 2578, 1.0], [1922, 1416, 1.0], [2330, 2329, 1.0], [666, 1973, 1.0], [2034, 791, 1.0], [1358, 758, 1.0], [270, 1215, 1.0], [2194, 214, 1.0], [2045, 1830, 1.0], [103, 608, 1.0], [2560, 1717, 1.0], [2560, 2561, 1.0], [1314, 1269, 1.0], [1215, 270, 1.0], [245, 1162, 1.0], [935, 661, 1.0], [2507, 2221, 1.0], [286, 698, 1.0], [1225, 2579, 1.0], [83, 2581, 1.0], [1000, 2543, 1.0], [904, 647, 1.0], [2649, 1915, 1.0], [2119, 33, 1.0], [2033, 1002, 1.0], [2464, 2290, 1.0], [559, 1182, 1.0], [353, 1173, 1.0], [1771, 1623, 1.0], [1772, 426, 1.0], [984, 2265, 1.0], [2182, 2172, 1.0], [626, 372, 1.0], [1035, 1433, 1.0], [1878, 2256, 1.0], [2581, 449, 1.0], [1013, 1850, 1.0], [710, 1392, 1.0], [2094, 441, 1.0], [436, 878, 1.0], [900, 639, 1.0], [1687, 1721, 1.0], [2229, 601, 1.0], [1932, 1413, 1.0], [2647, 473, 1.0], [1370, 1224, 1.0], [2671, 726, 1.0], [190, 491, 1.0], [1269, 1880, 1.0], [484, 542, 1.0], [2249, 2518, 1.0], [228, 1871, 1.0], [657, 871, 1.0], [861, 95, 1.0], [1908, 1677, 1.0], [1517, 1042, 1.0], [1972, 1652, 1.0], [2578, 2360, 1.0], [2685, 732, 1.0], [468, 1313, 1.0], [2045, 306, 1.0], [902, 1284, 1.0], [1604, 46, 1.0], [428, 1257, 1.0], [2211, 1065, 1.0], [2145, 1512, 1.0], [547, 598, 1.0], [2205, 1952, 1.0], [800, 889, 1.0], [1701, 1862, 1.0], [2071, 755, 1.0], [2503, 1038, 1.0], [2114, 2519, 1.0], [316, 143, 1.0], [643, 1538, 1.0], [1360, 2491, 1.0], [1536, 1228, 1.0], [169, 2706, 1.0], [2597, 1734, 1.0], [1095, 230, 1.0], [1674, 1914, 1.0], [1556, 888, 1.0], [1073, 985, 1.0], [88, 1713, 1.0], [831, 1011, 1.0]]:
# Loss 17
# ['node 382 from 4 to 3', 'node 504 from 6 to 0', 'node 626 from 1 to 2', 'node 830 from 6 to 5', 'node 888 from 2 to 0', 'node 985 from 3 to 2', 'node 1120 from 0 to 6', 'node 1215 from 0 to 3', 'node 1804 from 1 to 2', 'node 1932 from 3 to 4', 'node 1977 from 5 to 0', 'node 1981 from 5 to 0', 'node 2119 from 4 to 3', 'node 2229 from 3 to 5', 'node 2256 from 5 to 1', 'node 2558 from 1 to 2', 'node 2561 from 0 to 2']
#
#
# remove edge:[[2436, 2031, 1.0], [73, 1189, 1.0], [1052, 1701, 1.0], [2238, 1702, 1.0], [1031, 48, 1.0], [112, 1623, 1.0], [72, 1103, 1.0], [2653, 1920, 1.0], [1149, 1986, 1.0], [2068, 1330, 1.0], [1399, 2227, 1.0], [1065, 85, 1.0], [2344, 2475, 1.0], [2117, 2118, 1.0], [1420, 2394, 1.0], [1580, 95, 1.0], [22, 1234, 1.0], [144, 1593, 1.0], [606, 2361, 1.0], [1837, 997, 1.0], [1273, 1119, 1.0], [854, 1097, 1.0], [936, 2515, 1.0], [1310, 2692, 1.0], [1914, 1916, 1.0], [689, 1721, 1.0], [1395, 2189, 1.0], [406, 505, 1.0], [1724, 768, 1.0], [2155, 1131, 1.0], [1441, 2274, 1.0], [1701, 1636, 1.0], [180, 159, 1.0], [441, 454, 1.0], [213, 145, 1.0], [473, 2647, 1.0], [2252, 121, 1.0], [1355, 1957, 1.0], [454, 2022, 1.0], [102, 1251, 1.0], [2249, 368, 1.0], [1177, 295, 1.0], [1824, 1267, 1.0], [462, 1048, 1.0], [1644, 415, 1.0], [475, 2219, 1.0], [2163, 2162, 1.0], [1448, 2034, 1.0], [131, 2169, 1.0], [1721, 687, 1.0], [1078, 591, 1.0], [154, 326, 1.0], [734, 736, 1.0], [1317, 1306, 1.0], [1914, 1675, 1.0], [2291, 2268, 1.0], [836, 1131, 1.0], [695, 2319, 1.0], [1000, 972, 1.0], [1452, 1015, 1.0], [1519, 147, 1.0], [512, 240, 1.0], [2240, 1157, 1.0], [2027, 2360, 1.0], [16, 2642, 1.0], [638, 783, 1.0], [595, 1256, 1.0], [693, 1851, 1.0], [1978, 621, 1.0], [1776, 138, 1.0], [1126, 1823, 1.0], [1241, 1950, 1.0], [1414, 1415, 1.0], [957, 1757, 1.0], [1785, 1624, 1.0], [1919, 1914, 1.0], [440, 1913, 1.0], [716, 603, 1.0], [1263, 1407, 1.0], [306, 719, 1.0], [1394, 211, 1.0], [2314, 1708, 1.0], [1251, 1448, 1.0], [376, 1583, 1.0], [365, 2469, 1.0], [2034, 1270, 1.0], [1413, 1936, 1.0], [91, 1046, 1.0], [580, 1742, 1.0], [2009, 160, 1.0], [158, 180, 1.0], [99, 2455, 1.0], [53, 1739, 1.0], [284, 2224, 1.0], [2110, 1421, 1.0], [1772, 1782, 1.0], [889, 800, 1.0], [1009, 306, 1.0], [1766, 1358, 1.0], [1172, 467, 1.0]]:
# Loss 14
# ['node 376 from 6 to 5', 'node 462 from 2 to 4', 'node 504 from 6 to 0', 'node 679 from 3 to 0', 'node 985 from 3 to 2', 'node 1048 from 2 to 6', 'node 1394 from 0 to 5', 'node 1681 from 1 to 3', 'node 1837 from 3 to 1', 'node 2027 from 3 to 0', 'node 2137 from 0 to 4', 'node 2262 from 4 to 3', 'node 2274 from 0 to 5', 'node 2653 from 6 to 4']
#
#
# remove edge:[[367, 2451, 1.0], [962, 1807, 1.0], [2398, 2493, 1.0], [2211, 2356, 1.0], [1623, 1768, 1.0], [733, 1682, 1.0], [1079, 1914, 1.0], [1147, 2367, 1.0], [1724, 1723, 1.0], [2045, 153, 1.0], [2034, 49, 1.0], [1628, 1540, 1.0], [1671, 1968, 1.0], [1270, 1622, 1.0], [1655, 1894, 1.0], [1652, 604, 1.0], [2395, 2394, 1.0], [428, 1257, 1.0], [1869, 420, 1.0], [210, 1907, 1.0], [1542, 1935, 1.0], [2693, 2636, 1.0], [1735, 1282, 1.0], [105, 2651, 1.0], [1868, 231, 1.0], [2168, 834, 1.0], [791, 2034, 1.0], [2229, 266, 1.0], [738, 30, 1.0], [887, 910, 1.0], [1717, 1114, 1.0], [2515, 1154, 1.0], [2327, 1490, 1.0], [961, 1728, 1.0], [1243, 1150, 1.0], [26, 2455, 1.0], [1004, 1489, 1.0], [2054, 525, 1.0], [1130, 833, 1.0], [53, 1739, 1.0], [2706, 169, 1.0], [713, 1044, 1.0], [1447, 1928, 1.0], [239, 1220, 1.0], [689, 1317, 1.0], [2612, 1280, 1.0], [243, 473, 1.0], [756, 512, 1.0], [1094, 1653, 1.0], [821, 222, 1.0], [1648, 1210, 1.0], [963, 1703, 1.0], [2367, 2370, 1.0], [690, 311, 1.0], [1185, 1992, 1.0], [687, 2359, 1.0], [1358, 1550, 1.0], [1257, 1135, 1.0], [897, 2295, 1.0], [1322, 2265, 1.0], [403, 464, 1.0], [355, 1668, 1.0], [1979, 2178, 1.0], [181, 1464, 1.0], [119, 1959, 1.0], [1973, 1525, 1.0], [2000, 314, 1.0], [236, 109, 1.0], [372, 1710, 1.0], [784, 1701, 1.0], [915, 2597, 1.0], [1483, 704, 1.0], [110, 1262, 1.0], [2335, 1385, 1.0], [2162, 30, 1.0], [2209, 1647, 1.0], [1929, 1268, 1.0], [80, 257, 1.0], [2180, 81, 1.0], [633, 0, 1.0], [750, 1441, 1.0], [1262, 1072, 1.0], [2181, 2196, 1.0], [1909, 239, 1.0], [2335, 2336, 1.0], [350, 1778, 1.0], [76, 2178, 1.0], [1202, 2336, 1.0], [701, 735, 1.0], [752, 2451, 1.0], [2291, 2233, 1.0], [1334, 1542, 1.0], [972, 2247, 1.0], [1150, 1243, 1.0], [818, 415, 1.0], [1950, 1241, 1.0], [165, 2706, 1.0], [258, 1153, 1.0], [80, 2049, 1.0], [2166, 118, 1.0]]:
# Loss 15
# ['node 314 from 3 to 1', 'node 382 from 4 to 3', 'node 713 from 3 to 2', 'node 750 from 5 to 2', 'node 809 from 0 to 3', 'node 1004 from 2 to 3', 'node 1044 from 3 to 4', 'node 1079 from 0 to 4', 'node 1131 from 5 to 0', 'node 1185 from 3 to 4', 'node 1652 from 6 to 0', 'node 1929 from 4 to 3', 'node 2168 from 1 to 2', 'node 2208 from 5 to 2', 'node 2211 from 4 to 2']
#
#
# remove edge:[[71, 206, 1.0], [1522, 2680, 1.0], [868, 2276, 1.0], [1583, 1120, 1.0], [2045, 109, 1.0], [1677, 88, 1.0], [1358, 1732, 1.0], [207, 833, 1.0], [340, 584, 1.0], [1661, 109, 1.0], [1125, 1042, 1.0], [1740, 1725, 1.0], [868, 2099, 1.0], [919, 1358, 1.0], [189, 1262, 1.0], [1980, 2405, 1.0], [1224, 1525, 1.0], [1870, 598, 1.0], [1535, 95, 1.0], [27, 1810, 1.0], [1795, 1794, 1.0], [2373, 267, 1.0], [656, 306, 1.0], [1065, 1699, 1.0], [88, 851, 1.0], [2419, 65, 1.0], [302, 306, 1.0], [732, 1756, 1.0], [1813, 1424, 1.0], [2692, 1310, 1.0], [1441, 2271, 1.0], [807, 1226, 1.0], [1072, 1740, 1.0], [132, 479, 1.0], [428, 1257, 1.0], [2476, 1596, 1.0], [2065, 918, 1.0], [2196, 2181, 1.0], [154, 1753, 1.0], [1527, 88, 1.0], [470, 1097, 1.0], [2317, 25, 1.0], [2668, 2667, 1.0], [2515, 1154, 1.0], [1608, 546, 1.0], [2491, 1360, 1.0], [756, 240, 1.0], [1810, 1787, 1.0], [482, 1812, 1.0], [2054, 95, 1.0], [45, 2303, 1.0], [1889, 429, 1.0], [525, 408, 1.0], [809, 2229, 1.0], [1738, 1358, 1.0], [897, 1907, 1.0], [598, 519, 1.0], [2273, 1441, 1.0], [1026, 2531, 1.0], [2335, 1481, 1.0], [2103, 2385, 1.0], [1891, 2034, 1.0], [1204, 1838, 1.0], [1050, 1634, 1.0], [2455, 123, 1.0], [1287, 59, 1.0], [1199, 1716, 1.0], [1013, 1844, 1.0], [702, 2070, 1.0], [1534, 911, 1.0], [1120, 1110, 1.0], [325, 787, 1.0], [828, 1795, 1.0], [2248, 428, 1.
# Loss 17
# ['node 252 from 5 to 6', 'node 255 from 6 to 3', 'node 382 from 4 to 5', 'node 504 from 6 to 0', 'node 577 from 3 to 4', 'node 600 from 4 to 0', 'node 748 from 2 to 0', 'node 830 from 6 to 5', 'node 851 from 5 to 0', 'node 989 from 6 to 5', 'node 1185 from 3 to 4', 'node 1198 from 0 to 3', 'node 1288 from 5 to 0', 'node 1419 from 4 to 3', 'node 1556 from 0 to 2', 'node 1637 from 0 to 5', 'node 2262 from 4 to 3']
#
#
# ...
# Loss 10
# ['node 577 from 3 to 4', 'node 849 from 3 to 4', 'node 995 from 0 to 3', 'node 1131 from 5 to 0', 'node 1268 from 4 to 0', 'node 1399 from 6 to 5', 'node 1909 from 3 to 0', 'node 2137 from 0 to 6', 'node 2347 from 0 to 4', 'node 2413 from 1 to 2']
#
#
# remove edge:[[1883, 661, 1.0], [2206, 1952, 1.0], [754, 2450, 1.0], [1810, 795, 1.0], [1065, 864, 1.0], [1199, 1214, 1.0], [1072, 1262, 1.0], [162, 323, 1.0], [71, 206, 1.0], [2227, 266, 1.0], [1309, 61, 1.0], [1269, 1314, 1.0], [1131, 2280, 1.0], [2636, 2693, 1.0], [1893, 920, 1.0], [2383, 893, 1.0], [316, 920, 1.0], [2147, 2486, 1.0], [2555, 2599, 1.0], [2642, 364, 1.0], [1348, 1810, 1.0], [370, 128, 1.0], [1121, 835, 1.0], [601, 2229, 1.0], [733, 45, 1.0], [838, 2280, 1.0], [284, 2222, 1.0], [577, 906, 1.0], [525, 2172, 1.0], [1309, 1741, 1.0], [1735, 1776, 1.0], [1072, 1070, 1.0], [530, 1013, 1.0], [1054, 990, 1.0], [1546, 687, 1.0], [2304, 733, 1.0], [2414, 2413, 1.0], [415, 1908, 1.0], [458, 1555, 1.0], [2318, 1681, 1.0], [1692, 1469, 1.0], [719, 306, 1.0], [999, 346, 1.0], [1577, 1334, 1.0], [12, 2661, 1.0], [2016, 842, 1.0], [2083, 1550, 1.0], [971, 1650, 1.0], [1195, 279, 1.0], [1472, 756, 1.0], [1283, 1776, 1.0], [1701, 1864, 1.0], [1749, 1358, 1.0], [81, 347, 1.0], [377, 678, 1.0], [1878, 2256, 1.0], [1725, 2597, 1.0], [118, 1029, 1.0], [1373, 848, 1.0], [2442, 2614, 1.0], [143, 316, 1.0], [552, 1358, 1.0], [102, 1623, 1.0], [867, 2442, 1.0], [2165, 118, 1.0], [1358, 1516, 1.0], [982, 2176, 1.0], [2228, 1396, 1.0], [15, 1093, 1.0], [1358, 111, 1.0], [443, 1264, 1.0], [1699, 1505, 1.0], [974, 1496, 1.0], [299, 2498, 1.0], [370, 2269, 1.0], [96, 2217, 1.0], [466, 970, 1.0], [1829, 1070, 1.0], [266, 2229, 1.0], [1689, 155, 1.0], [146, 897, 1.0], [1581, 1819, 1.0], [1810, 1331, 1.0], [598, 845, 1.0], [361, 2681, 1.0], [2434, 2401, 1.0], [2556, 626, 1.0], [518, 1373, 1.0], [2146, 846, 1.0], [2072, 1602, 1.0], [1072, 1804, 1.0], [2178, 2024, 1.0], [1111, 2125, 1.0], [1429, 2520, 1.0], [2172, 525, 1.0], [27, 2578, 1.0], [616, 1358, 1.0], [1452, 1336, 1.0], [276, 1695, 1.0], [1983, 897, 1.0]]:
# Loss 14
# ['node 361 from 4 to 2', 'node 809 from 0 to 5', 'node 830 from 6 to 5', 'node 920 from 3 to 4', 'node 974 from 6 to 5', 'node 1111 from 4 to 3', 'node 1121 from 3 to 0', 'node 1399 from 6 to 5', 'node 2015 from 0 to 5', 'node 2016 from 6 to 5', 'node 2228 from 6 to 5', 'node 2256 from 5 to 1', 'node 2347 from 0 to 4', 'node 2413 from 1 to 3']
#
#
# remove edge:[[281, 2247, 1.0], [1581, 1810, 1.0], [1429, 2520, 1.0], [2157, 2160, 1.0], [1395, 679, 1.0], [2285, 2286, 1.0], [1640, 350, 1.0], [1776, 337, 1.0], [99, 26, 1.0], [1955, 807, 1.0], [1537, 1455, 1.0], [870, 2126, 1.0], [437, 498, 1.0], [306, 2078, 1.0], [2059, 1435, 1.0], [1313, 1312, 1.0], [1647, 108, 1.0], [1179, 410, 1.0], [1852, 2045, 1.0], [2063, 1326, 1.0], [1149, 1358, 1.0], [1281, 1746, 1.0], [350, 1640, 1.0], [873, 1479, 1.0], [1443, 2399, 1.0], [1605, 1054, 1.0], [1666, 49, 1.0], [2394, 1420, 1.0], [1702, 1240, 1.0], [1573, 2698, 1.0], [930, 477, 1.0], [387, 519, 1.0], [578, 1105, 1.0], [236, 138, 1.0], [1634, 1050, 1.0], [1269, 1630, 1.0], [729, 2534, 1.0], [358, 2642, 1.0], [1279, 2203, 1.0], [2327, 1490, 1.0], [107, 1650, 1.0], [17, 927, 1.0], [1841, 736, 1.0], [1178, 1984, 1.0], [1655, 1410, 1.0], [1157, 2240, 1.0], [1546, 341, 1.0], [579, 994, 1.0], [733, 94, 1.0], [335, 1986, 1.0], [1579, 1182, 1.0], [1526, 1981, 1.0], [2581, 449, 1.0], [2122, 1051, 1.0], [523, 429, 1.0], [834, 876, 1.0], [2647, 473, 1.0], [1467, 52, 1.0], [867, 871, 1.0], [1479, 261, 1.0], [1778, 1771, 1.0], [1023, 2568, 1.0], [1954, 1956, 1.0], [2009, 160, 1.0], [1460, 2358, 1.0], [1226, 2528, 1.0], [1701, 231, 1.0], [1303, 979, 1.0], [3, 2544, 1.0], [2336, 2524, 1.0], [1663, 1462, 1.0], [1628, 2054, 1.0], [1862, 926, 1.0], [181, 1359, 1.0], [1451, 2564, 1.0], [515, 623, 1.0], [499, 2457, 1.0], [389, 359, 1.0], [2203, 2511, 1.0], [2217, 231, 1.0], [2189, 1395, 1.0], [2580, 1536, 1.0], [2452, 2451, 1.0], [2112, 118, 1.0], [2577, 1235, 1.0], [836, 708, 1.0], [350, 1775, 1.0], [1358, 1723, 1.0], [302, 1253, 1.0], [1655, 2282, 1.0], [1020, 180, 1.0], [1966, 1971, 1.0], [534, 609, 1.0], [1239, 743, 1.0], [103, 484, 1.0], [2455, 123, 1.0], [165, 1473, 1.0], [2117, 770, 1.0], [1653, 1585, 1.0], [310, 990, 1.0]]:
# Loss 12
# ['node 380 from 6 to 4', 'node 477 from 6 to 4', 'node 679 from 3 to 0', 'node 724 from 0 to 3', 'node 930 from 6 to 4', 'node 1131 from 5 to 0', 'node 1149 from 2 to 3', 'node 1666 from 4 to 3', 'node 1981 from 5 to 0', 'node 2394 from 6 to 0', 'node 2522 from 2 to 1', 'node 2569 from 6 to 4']
#
#
# remove edge:[[198, 1255, 1.0], [973, 880, 1.0], [2112, 2030, 1.0], [238, 1828, 1.0], [842, 87, 1.0], [1732, 1224, 1.0], [957, 752, 1.0], [1072, 958, 1.0], [2456, 672, 1.0], [2036, 833, 1.0], [1329, 994, 1.0], [384, 1623, 1.0], [309, 2268, 1.0], [1300, 877, 1.0], [1899, 2491, 1.0], [52, 2172, 1.0], [936, 2641, 1.0], [1973, 1975, 1.0], [394, 849, 1.0], [1841, 408, 1.0], [1082, 2386, 1.0], [304, 1172, 1.0], [452, 133, 1.0], [2446, 1716, 1.0], [446, 118, 1.0], [1549, 1901, 1.0], [2685, 732, 1.0], [2323, 1444, 1.0], [429, 2044, 1.0], [2372, 2359, 1.0], [918, 1098, 1.0], [507, 253, 1.0], [1696, 1713, 1.0], [1341, 2425, 1.0], [1101, 374, 1.0], [1889, 2039, 1.0], [375, 2435, 1.0], [2140, 17, 1.0], [134, 406, 1.0], [1701, 767, 1.0], [1443, 1094, 1.0], [2001, 2123, 1.0], [1528, 565, 1.0], [1377, 2068, 1.0], [441, 344, 1.0], [1441, 2275, 1.0], [911, 1534, 1.0], [1119, 1111, 1.0], [514, 120, 1.0], [95, 2183, 1.0], [2118, 1894, 1.0], [1678, 833, 1.0], [1367, 124, 1.0], [1097, 857, 1.0], [2321, 1682, 1.0], [240, 512, 1.0], [2086, 1505, 1.0], [1618, 429, 1.0], [323, 2022, 1.0], [1079, 1218, 1.0], [2335, 1474, 1.0], [1222, 925, 1.0], [2604, 123, 1.0], [391, 68, 1.0], [1317, 2221, 1.0], [2694, 431, 1.0], [1604, 1358, 1.0], [1214, 1716, 1.0], [580, 59, 1.0], [844, 264, 1.0], [945, 1072, 1.0], [943, 1196, 1.0], [2018, 356, 1.0], [1779, 1624, 1.0], [2498, 1484, 1.0], [779, 1973, 1.0], [387, 2191, 1.0], [1810, 1822, 1.0], [2033, 788, 1.0], [1780, 1624, 1.0], [2430, 570, 1.0], [2248, 1255, 1.0], [177, 726, 1.0], [470, 1115, 1.0], [170, 1067, 1.0], [1700, 1441, 1.0], [1914, 1920, 1.0], [2153, 2155, 1.0], [1366, 2248, 1.0], [541, 647, 1.0], [2450, 1620, 1.0], [796, 1103, 1.0], [1211, 507, 1.0], [1400, 2698, 1.0], [1087, 89, 1.0], [1810, 1004, 1.0], [1521, 1013, 1.0], [2548, 582, 1.0], [379, 904, 1.0], [678, 733, 1.0]]:
# Loss 16
# ['node 309 from 4 to 3', 'node 376 from 6 to 5', 'node 388 from 5 to 6', 'node 943 from 1 to 4', 'node 1079 from 0 to 4', 'node 1377 from 0 to 6', 'node 1444 from 2 to 5', 'node 1678 from 3 to 2', 'node 1700 from 5 to 3', 'node 1713 from 5 to 4', 'node 1869 from 3 to 4', 'node 2016 from 6 to 5', 'node 2036 from 3 to 4', 'node 2262 from 4 to 3', 'node 2274 from 0 to 5', 'node 2347 from 0 to 4']
#
#
# remove edge:[[2679, 2670, 1.0], [146, 897, 1.0], [1193, 1705, 1.0], [1666, 2381, 1.0], [1721, 105, 1.0], [1383, 806, 1.0], [1939, 19, 1.0], [1944, 336, 1.0], [2065, 918, 1.0], [1954, 2275, 1.0], [1376, 1848, 1.0], [1035, 1801, 1.0], [1460, 1185, 1.0], [2274, 1370, 1.0], [2181, 525, 1.0], [464, 2444, 1.0], [94, 733, 1.0], [2095, 109, 1.0], [1725, 1740, 1.0], [203, 1115, 1.0], [1519, 2640, 1.0], [1051, 911, 1.0], [2040, 2122, 1.0], [1443, 963, 1.0], [1628, 1139, 1.0], [1360, 904, 1.0], [845, 766, 1.0], [609, 1358, 1.0], [1602, 2054, 1.0], [2415, 915, 1.0], [2052, 544, 1.0], [1139, 1628, 1.0], [1680, 2576, 1.0], [814, 2383, 1.0], [109, 1998, 1.0], [1147, 395, 1.0], [691, 2034, 1.0], [1996, 2063, 1.0], [1682, 407, 1.0], [521, 598, 1.0], [948, 1682, 1.0], [89, 1401, 1.0], [2399, 963, 1.0], [1215, 270, 1.0], [228, 848, 1.0], [614, 2470, 1.0], [1682, 2321, 1.0], [1810, 27, 1.0], [1495, 93, 1.0], [1805, 556, 1.0], [1327, 2161, 1.0], [1901, 119, 1.0], [2, 332, 1.0], [1671, 210, 1.0], [442, 2120, 1.0], [1727, 1358, 1.0], [790, 1548, 1.0], [1143, 2376, 1.0], [833, 345, 1.0], [94, 1649, 1.0], [2472, 642, 1.0], [746, 281, 1.0], [1953, 1470, 1.0], [86, 1336, 1.0], [1853, 1701, 1.0], [2371, 2367, 1.0], [1224, 2156, 1.0], [2315, 1344, 1.0], [1763, 155, 1.0], [760, 1426, 1.0], [842, 2016, 1.0], [1966, 94, 1.0], [1973, 1976, 1.0], [1103, 998, 1.0], [1428, 2336, 1.0], [1537, 441, 1.0], [2269, 392, 1.0], [486, 435, 1.0], [816, 2405, 1.0], [1831, 889, 1.0], [1778, 350, 1.0], [1714, 1727, 1.0], [1417, 2350, 1.0], [306, 1705, 1.0], [1646, 1358, 1.0], [2556, 1249, 1.0], [1450, 1225, 1.0], [1269, 1227, 1.0], [1281, 1748, 1.0], [719, 303, 1.0], [2386, 885, 1.0], [410, 676, 1.0], [533, 1742, 1.0], [859, 1030, 1.0], [1608, 2489, 1.0], [2144, 137, 1.0], [82, 1138, 1.0], [1013, 1840, 1.0], [2199, 95, 1.0], [2176, 982, 1.0]]:
# Loss 14
# ['node 437 from 6 to 0', 'node 504 from 6 to 0', 'node 626 from 1 to 2', 'node 724 from 0 to 3', 'node 888 from 2 to 0', 'node 1131 from 5 to 0', 'node 1215 from 0 to 3', 'node 1291 from 5 to 6', 'node 1660 from 5 to 6', 'node 2262 from 4 to 3', 'node 2274 from 0 to 5', 'node 2371 from 3 to 6', 'node 2556 from 1 to 2', 'node 2637 from 1 to 4']
#
#
# remove edge:[[1755, 1765, 1.0], [1358, 337, 1.0], [1676, 1975, 1.0], [1778, 1367, 1.0], [718, 437, 1.0], [100, 1602, 1.0], [2123, 91, 1.0], [1806, 962, 1.0], [88, 130, 1.0], [2056, 1680, 1.0], [1153, 1401, 1.0], [2346, 1469, 1.0], [95, 736, 1.0], [583, 2224, 1.0], [1645, 1507, 1.0], [1472, 240, 1.0], [1297, 598, 1.0], [88, 2013, 1.0], [1666, 1662, 1.0], [2222, 284, 1.0], [669, 729, 1.0], [1453, 1986, 1.0], [699, 2327, 1.0], [728, 644, 1.0], [732, 263, 1.0], [1918, 506, 1.0], [871, 2530, 1.0], [844, 1902, 1.0], [1229, 1749, 1.0], [145, 213, 1.0], [980, 1367, 1.0], [2089, 2085, 1.0], [1255, 2248, 1.0], [1731, 1169, 1.0], [312, 1722, 1.0], [1365, 1702, 1.0], [133, 1784, 1.0], [905, 1282, 1.0], [1910, 121, 1.0], [1218, 1079, 1.0], [20, 2374, 1.0], [2112, 711, 1.0], [72, 1358, 1.0], [563, 318, 1.0], [1912, 2404, 1.0], [1097, 1115, 1.0], [1300, 2508, 1.0], [831, 1638, 1.0], [1850, 32, 1.0], [577, 906, 1.0], [486, 2668, 1.0], [1826, 1408, 1.0], [2386, 885, 1.0], [963, 1785, 1.0], [1103, 1123, 1.0], [1950, 1815, 1.0], [1701, 874, 1.0], [1499, 1776, 1.0], [1725, 687, 1.0], [1616, 447, 1.0], [1282, 741, 1.0], [2385, 1338, 1.0], [1211, 254, 1.0], [1593, 144, 1.0], [1813, 1810, 1.0], [2658, 1642, 1.0], [531, 606, 1.0], [840, 2481, 1.0], [2276, 868, 1.0], [918, 1542, 1.0], [596, 644, 1.0], [488, 444, 1.0], [2383, 808, 1.0], [798, 1794, 1.0], [2228, 1396, 1.0], [287, 2705, 1.0], [168, 2438, 1.0], [745, 1127, 1.0], [124, 1367, 1.0], [598, 165, 1.0], [2401, 2435, 1.0], [2054, 525, 1.0], [2197, 734, 1.0], [48, 2041, 1.0], [1556, 888, 1.0], [1598, 640, 1.0], [1941, 507, 1.0], [574, 2001, 1.0], [839, 485, 1.0], [1177, 1542, 1.0], [1671, 1614, 1.0], [552, 2201, 1.0], [1309, 1338, 1.0], [973, 277, 1.0], [1953, 458, 1.0], [223, 1154, 1.0], [231, 1868, 1.0], [1414, 371, 1.0], [1837, 1768, 1.0], [1805, 556, 1.0]]:
# Loss 16
# ['node 191 from 1 to 3', 'node 382 from 4 to 3', 'node 488 from 4 to 5', 'node 699 from 1 to 3', 'node 798 from 4 to 5', 'node 888 from 2 to 0', 'node 995 from 0 to 3', 'node 1288 from 5 to 0', 'node 1338 from 0 to 3', 'node 1813 from 3 to 4', 'node 1910 from 1 to 0', 'node 1912 from 0 to 3', 'node 2102 from 0 to 3', 'node 2103 from 0 to 3', 'node 2228 from 6 to 5', 'node 2347 from 0 to 4']
#
#
# remove edge:[[2269, 1619, 1.0], [1270, 2034, 1.0], [61, 1309, 1.0], [1598, 1147, 1.0], [1204, 1838, 1.0], [306, 2084, 1.0], [2509, 2114, 1.0], [1561, 1623, 1.0], [1499, 337, 1.0], [2094, 2106, 1.0], [52, 2172, 1.0], [1512, 945, 1.0], [1785, 317, 1.0], [598, 165, 1.0], [1959, 904, 1.0], [1663, 2577, 1.0], [1642, 439, 1.0], [170, 1358, 1.0], [719, 1810, 1.0], [496, 596, 1.0], [1810, 1821, 1.0], [1655, 11, 1.0], [1558, 879, 1.0], [2290, 444, 1.0], [1243, 1358, 1.0], [2282, 816, 1.0], [387, 519, 1.0], [1776, 1499, 1.0], [1568, 1358, 1.0], [1078, 591, 1.0], [623, 2464, 1.0], [2555, 961, 1.0], [1203, 1410, 1.0], [2636, 2634, 1.0], [2251, 2252, 1.0], [1215, 270, 1.0], [2671, 1257, 1.0], [1898, 755, 1.0], [733, 383, 1.0], [231, 176, 1.0], [1690, 118, 1.0], [687, 1171, 1.0], [436, 1980, 1.0], [1598, 1093, 1.0], [708, 2212, 1.0], [507, 2508, 1.0], [1218, 586, 1.0], [1188, 1187, 1.0], [558, 1189, 1.0], [153, 459, 1.0], [1739, 1709, 1.0], [314, 2000, 1.0], [712, 1464, 1.0], [2204, 2521, 1.0], [1792, 581, 1.0], [419, 349, 1.0], [30, 1358, 1.0], [1173, 1250, 1.0], [2003, 2001, 1.0], [1765, 1755, 1.0], [579, 994, 1.0], [1097, 1115, 1.0], [2681, 361, 1.0], [1169, 524, 1.0], [453, 2305, 1.0], [2100, 830, 1.0], [383, 2268, 1.0], [2034, 49, 1.0], [1358, 708, 1.0], [749, 1333, 1.0], [797, 800, 1.0], [472, 2029, 1.0], [877, 1413, 1.0], [796, 1358, 1.0], [1143, 2262, 1.0], [1953, 1555, 1.0], [1735, 1776, 1.0], [1992, 1986, 1.0], [160, 745, 1.0], [1452, 1417, 1.0], [581, 1616, 1.0], [415, 525, 1.0], [2533, 1201, 1.0], [38, 862, 1.0], [1425, 1015, 1.0], [1898, 645, 1.0], [1235, 2577, 1.0], [765, 2367, 1.0], [1128, 2275, 1.0], [1313, 468, 1.0], [1532, 39, 1.0], [297, 598, 1.0], [1868, 316, 1.0], [2495, 2494, 1.0], [1848, 2419, 1.0], [202, 1173, 1.0], [1623, 1775, 1.0], [2555, 2338, 1.0], [2240, 1443, 1.0], [901, 1042, 1.0]]:
# Loss 13
# ['node 314 from 3 to 1', 'node 382 from 4 to 3', 'node 383 from 4 to 3', 'node 581 from 6 to 1', 'node 708 from 3 to 2', 'node 830 from 6 to 5', 'node 1131 from 5 to 0', 'node 1201 from 3 to 0', 'node 1215 from 0 to 3', 'node 2003 from 4 to 3', 'node 2101 from 6 to 0', 'node 2263 from 0 to 4', 'node 2533 from 3 to 0']
#
#
# remove edge:[[1358, 1721, 1.0], [1347, 1997, 1.0], [973, 2019, 1.0], [27, 606, 1.0], [1326, 928, 1.0], [1372, 1362, 1.0], [1481, 2332, 1.0], [777, 702, 1.0], [1507, 989, 1.0], [1154, 2515, 1.0], [36, 2107, 1.0], [2670, 837, 1.0], [2224, 75, 1.0], [716, 1810, 1.0], [2498, 1484, 1.0], [1849, 56, 1.0], [2213, 710, 1.0], [2671, 1688, 1.0], [541, 1360, 1.0], [2219, 485, 1.0], [234, 2591, 1.0], [506, 1013, 1.0], [963, 1703, 1.0], [338, 1542, 1.0], [1929, 1927, 1.0], [1628, 1139, 1.0], [685, 554, 1.0], [1705, 487, 1.0], [1131, 2283, 1.0], [511, 549, 1.0], [758, 2492, 1.0], [1870, 598, 1.0], [1985, 437, 1.0], [373, 1025, 1.0], [2567, 953, 1.0], [2380, 2123, 1.0], [760, 1513, 1.0], [1100, 1701, 1.0], [2560, 2561, 1.0], [893, 911, 1.0], [1953, 1555, 1.0], [650, 1685, 1.0], [1950, 310, 1.0], [48, 2041, 1.0], [2318, 1779, 1.0], [568, 1810, 1.0], [2139, 2141, 1.0], [2198, 1042, 1.0], [252, 711, 1.0], [1542, 338, 1.0], [723, 9, 1.0], [2083, 650, 1.0], [2238, 627, 1.0], [1820, 1701, 1.0], [1721, 1761, 1.0], [1169, 2220, 1.0], [1939, 1542, 1.0], [651, 2156, 1.0], [1185, 2349, 1.0], [1119, 1462, 1.0], [454, 2189, 1.0], [2693, 2636, 1.0], [669, 729, 1.0], [162, 1667, 1.0], [2642, 358, 1.0], [2679, 1639, 1.0], [1344, 815, 1.0], [61, 2312, 1.0], [55, 771, 1.0], [278, 1185, 1.0], [598, 519, 1.0], [1675, 1676, 1.0], [645, 1267, 1.0], [1147, 2371, 1.0], [1810, 224, 1.0], [156, 1689, 1.0], [456, 544, 1.0], [1002, 622, 1.0], [2493, 157, 1.0], [709, 1896, 1.0], [2157, 108, 1.0], [1047, 1588, 1.0], [2530, 2439, 1.0], [2515, 2514, 1.0], [470, 1115, 1.0], [1186, 2574, 1.0], [842, 118, 1.0], [2333, 1588, 1.0], [2232, 315, 1.0], [368, 2249, 1.0], [904, 1360, 1.0], [1392, 51, 1.0], [1542, 918, 1.0], [2216, 1724, 1.0], [1299, 598, 1.0], [962, 1810, 1.0], [1902, 793, 1.0], [665, 576, 1.0], [996, 1135, 1.0], [168, 2438, 1.0]]:
# Loss 13
# ['node 162 from 4 to 0', 'node 437 from 6 to 0', 'node 724 from 0 to 3', 'node 777 from 0 to 6', 'node 1119 from 3 to 4', 'node 1185 from 3 to 4', 'node 1268 from 4 to 0', 'node 1671 from 3 to 4', 'node 1681 from 1 to 3', 'node 2318 from 1 to 0', 'node 2561 from 0 to 2', 'node 2567 from 4 to 2', 'node 2637 from 1 to 4']
#
#
# change rate: 0.1213
